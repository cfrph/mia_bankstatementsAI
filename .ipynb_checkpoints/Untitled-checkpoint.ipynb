# %%
# !pip install google-cloud-documentai
# Out:
# Collecting google-cloud-documentai
#   Downloading google_cloud_documentai-3.7.0-py3-none-any.whl (303 kB)
#      -------------------------------------- 303.0/303.0 kB 1.0 MB/s eta 0:00:00
# Collecting grpcio<2.0.0,>=1.33.2
#   Downloading grpcio-1.76.0-cp310-cp310-win_amd64.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 3.6 MB/s eta 0:00:00
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1
#   Downloading google_auth-2.43.0-py2.py3-none-any.whl (223 kB)
#      -------------------------------------- 223.1/223.1 kB 6.9 MB/s eta 0:00:00
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2
#   Downloading protobuf-6.33.0-cp310-abi3-win_amd64.whl (436 kB)
#      -------------------------------------- 436.9/436.9 kB 4.5 MB/s eta 0:00:00
# Collecting google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1
#   Downloading google_api_core-2.28.1-py3-none-any.whl (173 kB)
#      -------------------------------------- 173.7/173.7 kB 5.3 MB/s eta 0:00:00
# Collecting proto-plus<2.0.0,>=1.22.3
#   Downloading proto_plus-1.26.1-py3-none-any.whl (50 kB)
#      ---------------------------------------- 50.2/50.2 kB ? eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\cfrph\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-documentai) (2.32.5)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2
#   Downloading googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
#      -------------------------------------- 297.5/297.5 kB 9.0 MB/s eta 0:00:00
# Collecting grpcio-status<2.0.0,>=1.33.2
#   Downloading grpcio_status-1.76.0-py3-none-any.whl (14 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
#      -------------------------------------- 181.3/181.3 kB 5.5 MB/s eta 0:00:00
# Collecting cachetools<7.0,>=2.0.0
#   Downloading cachetools-6.2.1-py3-none-any.whl (11 kB)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\cfrph\anaconda3\lib\site-packages (from grpcio<2.0.0,>=1.33.2->google-cloud-documentai) (4.15.0)
# Collecting pyasn1<0.7.0,>=0.6.1
#   Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
#      ---------------------------------------- 83.1/83.1 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cfrph\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-documentai) (2025.10.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cfrph\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-documentai) (3.7)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\cfrph\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-documentai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cfrph\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-documentai) (2.2.2)
# Installing collected packages: pyasn1, protobuf, grpcio, cachetools, rsa, pyasn1-modules, proto-plus, googleapis-common-protos, grpcio-status, google-auth, google-api-core, google-cloud-documentai
# Successfully installed cachetools-6.2.1 google-api-core-2.28.1 google-auth-2.43.0 google-cloud-documentai-3.7.0 googleapis-common-protos-1.72.0 grpcio-1.76.0 grpcio-status-1.76.0 proto-plus-1.26.1 protobuf-6.33.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 rsa-4.9.1
# WARNING: Ignoring invalid distribution -mpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\cfrph\anaconda3\lib\site-packages)

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "path/to/your/service-account.json"

# %%
from google.cloud import documentai_v1 as documentai

# Set up client
client = documentai.DocumentProcessorServiceClient()

# Processor resource name
name = "projects/24637693419/locations/us/processors/e8c76bc446687873"

# Load PDF from local file or GCS
with open("statement.pdf", "rb") as f:
    raw_document = documentai.RawDocument(content=f.read(), mime_type="application/pdf")

# Prepare request
request = documentai.ProcessRequest(name=name, raw_document=raw_document)

# Process document
result = client.process_document(request=request)

# Print extracted entities
for entity in result.document.entities:
    print(f"{entity.type_}: {entity.mention_text} (confidence: {entity.confidence})")
# Out:
# C:\Users\cfrph\anaconda3\lib\site-packages\google\api_core\_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.14) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[3], line 4
#       1 from google.cloud import documentai_v1 as documentai
#       3 # Set up client
# ----> 4 client = documentai.DocumentProcessorServiceClient()
#       6 # Processor resource name
#       7 name = "projects/24637693419/locations/us/processors/e8c76bc446687873"
#
# File ~\anaconda3\lib\site-packages\google\cloud\documentai_v1\services\document_processor_service\client.py:802, in DocumentProcessorServiceClient.__init__(self, credentials, transport, client_options, client_info)
#     793     transport_init: Union[
#     794         Type[DocumentProcessorServiceTransport],
#     795         Callable[..., DocumentProcessorServiceTransport],
#    (...)
#     799         else cast(Callable[..., DocumentProcessorServiceTransport], transport)
#     800     )
#     801     # initialize with the provided callable or the passed in class
# --> 802     self._transport = transport_init(
#     803         credentials=credentials,
#     804         credentials_file=self._client_options.credentials_file,
#     805         host=self._api_endpoint,
#     806         scopes=self._client_options.scopes,
#     807         client_cert_source_for_mtls=self._client_cert_source,
#     808         quota_project_id=self._client_options.quota_project_id,
#     809         client_info=client_info,
#     810         always_use_jwt_access=True,
#     811         api_audience=self._client_options.api_audience,
#     812     )
#     814 if "async" not in str(self._transport):
#     815     if CLIENT_LOGGING_SUPPORTED and _LOGGER.isEnabledFor(
#     816         std_logging.DEBUG
#     817     ):  # pragma: NO COVER
#
# File ~\anaconda3\lib\site-packages\google\cloud\documentai_v1\services\document_processor_service\transports\grpc.py:243, in DocumentProcessorServiceGrpcTransport.__init__(self, host, credentials, credentials_file, scopes, channel, api_mtls_endpoint, client_cert_source, ssl_channel_credentials, client_cert_source_for_mtls, quota_project_id, client_info, always_use_jwt_access, api_audience)
#     238             self._ssl_channel_credentials = grpc.ssl_channel_credentials(
#     239                 certificate_chain=cert, private_key=key
#     240             )
#     242 # The base transport sets the host, credentials and scopes
# --> 243 super().__init__(
#     244     host=host,
#     245     credentials=credentials,
#     246     credentials_file=credentials_file,
#     247     scopes=scopes,
#     248     quota_project_id=quota_project_id,
#     249     client_info=client_info,
#     250     always_use_jwt_access=always_use_jwt_access,
#     251     api_audience=api_audience,
#     252 )
#     254 if not self._grpc_channel:
#     255     # initialize with the provided callable or the default channel
#     256     channel_init = channel or type(self).create_channel
#
# File ~\anaconda3\lib\site-packages\google\cloud\documentai_v1\services\document_processor_service\transports\base.py:109, in DocumentProcessorServiceTransport.__init__(self, host, credentials, credentials_file, scopes, quota_project_id, client_info, always_use_jwt_access, api_audience, **kwargs)
#     105     credentials, _ = google.auth.load_credentials_from_file(
#     106         credentials_file, **scopes_kwargs, quota_project_id=quota_project_id
#     107     )
#     108 elif credentials is None and not self._ignore_credentials:
# --> 109     credentials, _ = google.auth.default(
#     110         **scopes_kwargs, quota_project_id=quota_project_id
#     111     )
#     112     # Don't apply audience if the credentials file passed from user.
#     113     if hasattr(credentials, "with_gdch_audience"):
#
# File ~\anaconda3\lib\site-packages\google\auth\_default.py:739, in default(scopes, request, quota_project_id, default_scopes)
#     731             _LOGGER.warning(
#     732                 "No project ID could be determined. Consider running "
#     733                 "`gcloud config set project` or setting the %s "
#     734                 "environment variable",
#     735                 environment_vars.PROJECT,
#     736             )
#     737         return credentials, effective_project_id
# --> 739 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.

# %%
# !pip install google-cloud-documentai
# Out:
# Requirement already satisfied: google-cloud-documentai in c:\users\cfrph\anaconda3\lib\site-packages (3.7.0)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in c:\users\cfrph\anaconda3\lib\site-packages (from google-cloud-documentai) (2.28.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\cfrph\anaconda3\lib\site-packages (from google-cloud-documentai) (1.76.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\cfrph\anaconda3\lib\site-packages (from google-cloud-documentai) (1.26.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in c:\users\cfrph\anaconda3\lib\site-packages (from google-cloud-documentai) (2.43.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\users\cfrph\anaconda3\lib\site-packages (from google-cloud-documentai) (6.33.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\cfrph\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-documentai) (1.72.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\cfrph\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-documentai) (2.32.5)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\cfrph\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-documentai) (1.76.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\cfrph\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-documentai) (0.4.2)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\cfrph\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-documentai) (6.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\cfrph\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-documentai) (4.9.1)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\cfrph\anaconda3\lib\site-packages (from grpcio<2.0.0,>=1.33.2->google-cloud-documentai) (4.15.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\cfrph\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-documentai) (0.6.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cfrph\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-documentai) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cfrph\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-documentai) (2025.10.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\cfrph\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-documentai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cfrph\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-documentai) (3.7)
# WARNING: Ignoring invalid distribution -mpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\cfrph\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\cfrph\anaconda3\lib\site-packages)

# %%
from google.cloud import documentai_v1 as documentai
from google.cloud.documentai_v1 import types
import os

# Set your Google Cloud project variables
PROJECT_ID = "linear-poet-477701-q6"
LOCATION = "us"  # processor location
PROCESSOR_ID = "e8c76bc446687873"

# Path to the PDF file to test
FILE_PATH = "2025-0926-to-0930-TCB.pdf"

def process_document():
    # Instantiates a client
    client = documentai.DocumentProcessorServiceClient()

    # The full resource name of the processor
    name = f"projects/{PROJECT_ID}/locations/{LOCATION}/processors/{PROCESSOR_ID}"

    # Read the file into memory
    with open(FILE_PATH, "rb") as file:
        file_content = file.read()

    document = {
        "content": file_content,
        "mime_type": "application/pdf"
    }

    request = {
        "name": name,
        "raw_document": document
    }

    # Use the Document AI client to process the document
    response = client.process_document(request=request)

    # Get the document object from the response
    document = response.document

    # Print the document text (optional)
    print("Document Text:")
    print(document.text)

    # Print the full JSON response for inspection
    print("\nFull Document AI Response:")
    print(response)

if __name__ == "__main__":
    process_document()
